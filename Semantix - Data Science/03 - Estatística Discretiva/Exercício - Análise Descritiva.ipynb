# %%
# ! pip install numpy pandas matplotlib seaborn missingno

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Seção 1 - Importando Arquivos

# %%
df = pd.read_csv('./risco_credito.csv')
df.head()
# Out:
#   default  t_risco  valor_emprestimo  prazo_pagamento  limite_credito  \
# 0   False     0.43          20024.31             60.0         62386.0
# 1   False     0.23          10046.51             36.0             NaN
# 2   False     0.30          21228.25             60.0             NaN
# 3   False     0.15          23032.33             36.0             NaN
# 4   False     0.08          24026.29             36.0         32366.0
#
#       renda signo genero perfil_facebook  n_emprestimos_inadiplentes
# 0  59869.05  virg      f            True                         0.0
# 1  46016.31  sagi      f           False                         0.0
# 2  48025.47  libr      m            True                         0.0
# 3  46011.12   NaN      m           False                         0.0
# 4  90026.17  libr      m             NaN                         0.0

# %%
def show_info(data):
    print('DATASET SHAPE: ', data.shape, end='\n')
    print('-'*50)
    print('FEATURE DATA TYPES')
    print(data.info())
    print('-'*50)
    print('NUMBER OF UNIQUE VALUES PER FEATURE:', end='\n')
    print(data.nunique())   
    print('\n', '-'*50)
    print('NULL VALUES PER FEATURE:')
    print(data.isnull().sum())   

show_info(df)
# Out:
# DATASET SHAPE:  (64592, 10)
# --------------------------------------------------
# FEATURE DATA TYPES
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64592 entries, 0 to 64591
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     59966 non-null  object
#  1   t_risco                     63807 non-null  float64
#  2   valor_emprestimo            63807 non-null  float64
#  3   prazo_pagamento             63807 non-null  float64
#  4   limite_credito              44839 non-null  float64
#  5   renda                       63807 non-null  float64
#  6   signo                       43825 non-null  object
#  7   genero                      57406 non-null  object
#  8   perfil_facebook             58185 non-null  object
#  9   n_emprestimos_inadiplentes  63789 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 4.9+ MB
# None
# --------------------------------------------------
# NUMBER OF UNIQUE VALUES PER FEATURE:
# default                           2
# t_risco                          82
# valor_emprestimo              53348
# prazo_pagamento                   2
# limite_credito                28259
# renda                         57430
# signo                            12
# genero                            2
# perfil_facebook                   2
# n_emprestimos_inadiplentes        5
# dtype: int64
#
#  --------------------------------------------------
# NULL VALUES PER FEATURE:
# default                        4626
# t_risco                         785
# valor_emprestimo                785
# prazo_pagamento                 785
# limite_credito                19753
# renda                           785
# signo                         20767
# genero                         7186
# perfil_facebook                6407
# n_emprestimos_inadiplentes      803
# dtype: int64

# %% [markdown]
# ## Seção 2  - Tratamento dos dados 1

# %%
msno.bar(df);

# %% [markdown]
# 1) Exclusão das linhas referentes a default que estão nulas

# %%
df = df.dropna(subset=['default'])

# %% [markdown]
# 2) Pelo resumo das variáveis quantitativas, o ideal é substituir os valores faltantes do limite de crétido e do númedo de empréstimos com inadiplência pela mediana

# %%
df.describe()
# Out:
#             t_risco  valor_emprestimo  prazo_pagamento  limite_credito  \
# count  59966.000000      59966.000000     59966.000000    41187.000000
# mean       0.294114      13411.805468        40.674649    34093.005997
# std        0.101183       7957.402823         9.504775    36783.480509
# min        0.000000        527.070000        36.000000        0.000000
# 25%        0.220000       7225.987500        36.000000     9907.000000
# 50%        0.290000      12012.400000        36.000000    25338.000000
# 75%        0.360000      18036.645000        36.000000    46759.500000
# max        0.900000      35059.600000        60.000000   613117.000000
#
#               renda  n_emprestimos_inadiplentes
# count  5.996600e+04                59948.000000
# mean   7.132578e+04                    0.004671
# std    5.169143e+04                    0.079059
# min    4.821180e+03                    0.000000
# 25%    4.402786e+04                    0.000000
# 50%    6.004726e+04                    0.000000
# 75%    8.503961e+04                    0.000000
# max    5.000028e+06                    5.000000

# %%
valores_preechimento = {
    'limite_credito': df['limite_credito'].median(),
    'n_emprestimos_inadiplentes': df['n_emprestimos_inadiplentes'].median(),    
}
df = df.fillna(value=valores_preechimento)

# %% [markdown]
# 3) Substituindo as qualitativas pela moda

# %%
df['genero'].value_counts()
# Out:
# m    38497
# f    18473
# Name: genero, dtype: int64

# %%
df['perfil_facebook'].value_counts()
# Out:
# False    33997
# True     19998
# Name: perfil_facebook, dtype: int64

# %%
df['signo'].value_counts()
# Out:
# libr     5582
# virg     5571
# cance    5541
# leo      3507
# gemi     3499
# scor     3091
# arie     3045
# pisce    2992
# capr     2958
# aqua     2839
# sagi     1402
# taur     1001
# Name: signo, dtype: int64

# %%
df['genero'] = df['genero'].fillna(df['genero'].mode()[0])
df['perfil_facebook'] = df['perfil_facebook'].fillna(df['perfil_facebook'].mode()[0])

# %%
df.isnull().sum()
# Out:
# default                           0
# t_risco                           0
# valor_emprestimo                  0
# prazo_pagamento                   0
# limite_credito                    0
# renda                             0
# signo                         18938
# genero                            0
# perfil_facebook                   0
# n_emprestimos_inadiplentes        0
# dtype: int64

# %% [markdown]
# ## Seção 3 - Análise exploratória e tratamento dos dados 2

# %% [markdown]
# 1) Variáveis Qualitativas

# %%
va_nominal = ['object', 'bool']
qualitativas = list(df.select_dtypes(include=va_nominal).columns)
qualitativas
# Out:
# ['default', 'signo', 'genero', 'perfil_facebook']

# %%
df_quali = df[qualitativas]
df_quali.head()
# Out:
#   default signo genero  perfil_facebook
# 0   False  virg      f             True
# 1   False  sagi      f            False
# 2   False  libr      m             True
# 3   False   NaN      m            False
# 4   False  libr      m            False

# %%
for va_nominal in df_quali:
    print(va_nominal)
    sns.countplot(df_quali[va_nominal], palette='flare')
    plt.show();
# Out:
# default
# signo
# genero
# perfil_facebook

# %% [markdown]
# 1. A variável resposta (**Default**) possui classes desbalanceadas;
# 2. **Signo**, as classes possuem contagens bem parecidas, só se destacando as contagens dos desconhecidos, que apresenta 31% dos dados, logo vou preferir apagar essas coluna do que perder informação dessas linhas;
# 3. **Genero**, o desconhecido será substituído por masculino, pois, possui uma frequência superios;
# 4. **Perfil_facebook**, o desconhecido será substituido por falso

# %%
df = df.drop(columns='signo')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59966 entries, 0 to 64591
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     59966 non-null  object
#  1   t_risco                     59966 non-null  float64
#  2   valor_emprestimo            59966 non-null  float64
#  3   prazo_pagamento             59966 non-null  float64
#  4   limite_credito              59966 non-null  float64
#  5   renda                       59966 non-null  float64
#  6   genero                      59966 non-null  object
#  7   perfil_facebook             59966 non-null  bool
#  8   n_emprestimos_inadiplentes  59966 non-null  float64
# dtypes: bool(1), float64(6), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# 2) Variáveis QUantitivativas

# %% [markdown]
# 1. A taxa de risco teve um pico em torno de 0.3;
# 2. 75% pediram empréstimo no valor de até 18036,6;
# 3. 75% tem limite de crédito até 35125 e o valor máximo foi de 613117;
# 4. 75% tem renda até 8500;
# 5. 75% não foram inadiplentes com empréstimos.

# %%
df.describe()
# Out:
#             t_risco  valor_emprestimo  prazo_pagamento  limite_credito  \
# count  59966.000000      59966.000000     59966.000000    59966.000000
# mean       0.294114      13411.805468        40.674649    31351.281393
# std        0.101183       7957.402823         9.504775    30753.702302
# min        0.000000        527.070000        36.000000        0.000000
# 25%        0.220000       7225.987500        36.000000    17316.500000
# 50%        0.290000      12012.400000        36.000000    25338.000000
# 75%        0.360000      18036.645000        36.000000    35125.000000
# max        0.900000      35059.600000        60.000000   613117.000000
#
#               renda  n_emprestimos_inadiplentes
# count  5.996600e+04                59966.000000
# mean   7.132578e+04                    0.004669
# std    5.169143e+04                    0.079048
# min    4.821180e+03                    0.000000
# 25%    4.402786e+04                    0.000000
# 50%    6.004726e+04                    0.000000
# 75%    8.503961e+04                    0.000000
# max    5.000028e+06                    5.000000

# %%
va_quantitativa = ['float64']
quantitativas = list(df.select_dtypes(include=va_quantitativa).columns)
quantitativas
# Out:
# ['t_risco',
#  'valor_emprestimo',
#  'prazo_pagamento',
#  'limite_credito',
#  'renda',
#  'n_emprestimos_inadiplentes']

# %%
df_quanti = df[quantitativas]

# %%
for va_quantitativa in df_quanti:
    print(va_quantitativa)
    df_quanti[va_quantitativa].hist(bins=10)
    plt.show();
# Out:
# t_risco
# valor_emprestimo
# prazo_pagamento
# limite_credito
# renda
# n_emprestimos_inadiplentes

# %% [markdown]
# 3) Análise Bivariada

# %% [markdown]
# Parece que os clientes consideradores com risco de não pagar o empréstimo, não há diferença entre o sexo e possuir ou não perfil no facebook

# %%
fig, ax = plt.subplots(2, 1, figsize=(10,10))
plt.tight_layout(1)

sns.countplot(df['genero'], hue=df.default, ax=ax[0], palette='Blues')
sns.countplot(df['perfil_facebook'], hue=df.default, ax=ax[1], palette='Blues');

# %%
for va_quantitativa in df_quanti:
    print(va_quantitativa)
    sns.boxplot(y=df_quanti[va_quantitativa], x='default', data=df, palette='flare')
    plt.show();
# Out:
# t_risco
# valor_emprestimo
# prazo_pagamento
# limite_credito
# renda
# n_emprestimos_inadiplentes

# %%
plt.figure(figsize=(20,5))
plt.title('Correlação entre as features', size=15)
sns.heatmap(df_quanti.corr(), cmap='flare', center=0, annot=True);

# %%
plt.figure(figsize=(15,7))
sns.pairplot(data=df, hue='default')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35408/136429437.py in <module>
#       1 plt.figure(figsize=(15,7))
# ----> 2 sns.pairplot(data=df, hue='default')
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128         diag_kws.setdefault("fill", True)
#    2129         diag_kws.setdefault("warn_singular", False)
# -> 2130         grid.map_diag(kdeplot, **diag_kws)
#    2131
#    2132     # Maybe plot on the off-diagonals
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478             func(x=vector, **plot_kwargs)
#    1479             ax.legend_ = None
#    1480
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1768             plot_kws["color"] = color
#    1769
# -> 1770         p.plot_univariate_density(
#    1771             multiple=multiple,
#    1772             common_norm=common_norm,
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, legend, estimate_kws, **plot_kws)
#     926
#     927         # Do the computation
# --> 928         densities = self._compute_univariate_density(
#     929             self.data_variable,
#     930             common_norm,
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     324
#     325             # Estimate the density of observations at this level
# --> 326             density, support = estimator(observations, weights=weights)
#     327
#     328             if log_scale:
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     185         """Fit and evaluate on univariate or bivariate data."""
#     186         if x2 is None:
# --> 187             return self._eval_univariate(x1, weights)
#     188         else:
#     189             return self._eval_bivariate(x1, x2, weights)
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     144         support = self.support
#     145         if support is None:
# --> 146             support = self.define_support(x, cache=False)
#     147
#     148         kde = self._fit(x, weights)
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     117         """Create the evaluation grid for a given data set."""
#     118         if x2 is None:
# --> 119             support = self._define_support_univariate(x1, weights)
#     120         else:
#     121             support = self._define_support_bivariate(x1, x2, weights)
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      89     def _define_support_univariate(self, x, weights):
#      90         """Create a 1D grid of evaluation points."""
# ---> 91         kde = self._fit(x, weights)
#      92         bw = np.sqrt(kde.covariance.squeeze())
#      93         grid = self._define_support_grid(
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     135             fit_kws["weights"] = weights
#     136
# --> 137         kde = stats.gaussian_kde(fit_data, **fit_kws)
#     138         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     139
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     204             self._neff = 1/sum(self._weights**2)
#     205
# --> 206         self.set_bandwidth(bw_method=bw_method)
#     207
#     208     def evaluate(self, points):
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     552             raise ValueError(msg)
#     553
# --> 554         self._compute_covariance()
#     555
#     556     def _compute_covariance(self):
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     564                                                bias=False,
#     565                                                aweights=self.weights))
# --> 566             self._data_inv_cov = linalg.inv(self._data_covariance)
#     567
#     568         self.covariance = self._data_covariance * self.factor**2
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     937
#     938     """
# --> 939     a1 = _asarray_validated(a, check_finite=check_finite)
#     940     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     941         raise ValueError('expected square matrix')
#
# ~/Desktop/DataScience-Studies/Semantix - Data Science/03 - Estatística Discretiva/.venv/lib/python3.9/site-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     294     if not objects_ok:
#     295         if a.dtype is np.dtype('O'):
# --> 296             raise ValueError('object arrays are not supported')
#     297     if as_inexact:
#     298         if not np.issubdtype(a.dtype, np.inexact):
#
# ValueError: object arrays are not supported

# %%
df.head()
# Out:
#   default  t_risco  valor_emprestimo  prazo_pagamento  limite_credito  \
# 0   False     0.43          20024.31             60.0         62386.0
# 1   False     0.23          10046.51             36.0         25338.0
# 2   False     0.30          21228.25             60.0         25338.0
# 3   False     0.15          23032.33             36.0         25338.0
# 4   False     0.08          24026.29             36.0         32366.0
#
#       renda genero  perfil_facebook  n_emprestimos_inadiplentes
# 0  59869.05      f             True                         0.0
# 1  46016.31      f            False                         0.0
# 2  48025.47      m             True                         0.0
# 3  46011.12      m            False                         0.0
# 4  90026.17      m            False                         0.0

# %% [markdown]
# 4) Transdormando em variáveis binárias

# %%
df = pd.get_dummies(df, columns=['prazo_pagamento', 'genero', 'perfil_facebook', 'default'], drop_first=True)

# %%
df.head()
# Out:
#    t_risco  valor_emprestimo  limite_credito     renda  \
# 0     0.43          20024.31         62386.0  59869.05
# 1     0.23          10046.51         25338.0  46016.31
# 2     0.30          21228.25         25338.0  48025.47
# 3     0.15          23032.33         25338.0  46011.12
# 4     0.08          24026.29         32366.0  90026.17
#
#    n_emprestimos_inadiplentes  prazo_pagamento_60.0  genero_m  \
# 0                         0.0                     1         0
# 1                         0.0                     0         0
# 2                         0.0                     1         1
# 3                         0.0                     0         1
# 4                         0.0                     0         1
#
#    perfil_facebook_True  default_True
# 0                     1             0
# 1                     0             0
# 2                     1             0
# 3                     0             0
# 4                     0             0

# %% [markdown]
# 5) Substituindo outlier por quantil

# %%
sns.boxplot(data=df, x='default_True', y='t_risco', palette='flare');

# %%
out_max = df['t_risco'].quantile(0.975)
out_max
# Out:
# 0.51

# %%
df.loc[df['t_risco'] > out_max, 't_risco'] = out_max

# %%
out_min = df['t_risco'].quantile(0.025)
out_min
# Out:
# 0.12

# %%
sns.boxplot(data=df, x='default_True', y='t_risco', palette='flare');
