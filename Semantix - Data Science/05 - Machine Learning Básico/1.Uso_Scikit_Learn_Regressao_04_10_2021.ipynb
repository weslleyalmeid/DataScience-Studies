# %% [markdown]
# **Autor** : Hader Aguiar Dias Azzini
#
# **e-mail**: hader.azzini@semantix.com.br

# %% [markdown]
# #  <a name="resumo"> RESUMO </a>
# [Voltar ao índice](#indice)
#
# Este notebook tem o objetivo de exibir o uso de o pacote *Scikit-learn*

# %% [markdown]
# #  <a name="indice">  Índice </a>

# %% [markdown]
# * [Resumo](#resumo)
# * [Índice](#indice)
# * [Questão 1 - Executar o exemplo de Regressão Linear](#secao_0)
# * [Questão 2 - Executar o exemplo de Ridge Regression](#secao_1)
# * [Conclusão](#conclusao)

# %% [markdown]
# #  <a name="secao_0"> Questão 1 - Executar o exemplo de Regressão Linear </a>
# [Voltar ao índice](#indice)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])

reg.coef_
# Out:
# array([0.5, 0.5])

# %%
import plotly.graph_objects as go
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
diabetes_X[:5]
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187235, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, -0.02632783, -0.00844872,
#         -0.01916334,  0.07441156, -0.03949338, -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, -0.00567061, -0.04559945,
#         -0.03419447, -0.03235593, -0.00259226,  0.00286377, -0.02593034],
#        [-0.08906294, -0.04464164, -0.01159501, -0.03665645,  0.01219057,
#          0.02499059, -0.03603757,  0.03430886,  0.02269202, -0.00936191],
#        [ 0.00538306, -0.04464164, -0.03638469,  0.02187235,  0.00393485,
#          0.01559614,  0.00814208, -0.00259226, -0.03199144, -0.04664087]])

# %%
diabetes_y[:5]
# Out:
# array([151.,  75., 141., 206., 135.])

# %%
# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# %%
diabetes_X[:5]
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469]])

# %%
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# %%
len(diabetes_X_train)
# Out:
# 422

# %%
len(diabetes_X_test)
# Out:
# 20

# %%
# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# Out:
# Coefficients:
#  [938.23786125]

# %%
# The coefficients
print('Intercept: \n', regr.intercept_)
# Out:
# Intercept:
#  152.91886182616167

# %%
# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
diabetes_X_test
# Out:
# array([[ 0.07786339],
#        [-0.03961813],
#        [ 0.01103904],
#        [-0.04069594],
#        [-0.03422907],
#        [ 0.00564998],
#        [ 0.08864151],
#        [-0.03315126],
#        [-0.05686312],
#        [-0.03099563],
#        [ 0.05522933],
#        [-0.06009656],
#        [ 0.00133873],
#        [-0.02345095],
#        [-0.07410811],
#        [ 0.01966154],
#        [-0.01590626],
#        [-0.01590626],
#        [ 0.03906215],
#        [-0.0730303 ]])

# %%
diabetes_y_pred
# Out:
# array([225.9732401 , 115.74763374, 163.27610621, 114.73638965,
#        120.80385422, 158.21988574, 236.08568105, 121.81509832,
#         99.56772822, 123.83758651, 204.73711411,  96.53399594,
#        154.17490936, 130.91629517,  83.3878227 , 171.36605897,
#        137.99500384, 137.99500384, 189.56845268,  84.3990668 ])

# %%
diabetes_y_test
# Out:
# array([233.,  91., 111., 152., 120.,  67., 310.,  94., 183.,  66., 173.,
#         72.,  49.,  64.,  48., 178., 104., 132., 220.,  57.])

# %%
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Out:
# Mean squared error: 2548.07

# %%
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficient of determination: 0.47

# %%
diabetes_X.reshape(442)
# Out:
# array([ 0.06169621, -0.05147406,  0.04445121, -0.01159501, -0.03638469,
#        -0.04069594, -0.04716281, -0.00189471,  0.06169621,  0.03906215,
#        -0.08380842,  0.01750591, -0.02884001, -0.00189471, -0.02560657,
#        -0.01806189,  0.04229559,  0.01211685, -0.0105172 , -0.01806189,
#        -0.05686312, -0.02237314, -0.00405033,  0.06061839,  0.03582872,
#        -0.01267283, -0.07734155,  0.05954058, -0.02129532, -0.00620595,
#         0.04445121, -0.06548562,  0.12528712, -0.05039625, -0.06332999,
#        -0.03099563,  0.02289497,  0.01103904,  0.07139652,  0.01427248,
#        -0.00836158, -0.06764124, -0.0105172 , -0.02345095,  0.06816308,
#        -0.03530688, -0.01159501, -0.0730303 , -0.04177375,  0.01427248,
#        -0.00728377,  0.0164281 , -0.00943939, -0.01590626,  0.0250506 ,
#        -0.04931844,  0.04121778, -0.06332999, -0.06440781, -0.02560657,
#        -0.00405033,  0.00457217, -0.00728377, -0.0374625 , -0.02560657,
# ...

# %%
diabetes_y_line = regr.predict(diabetes_X)

# %%
diabetes_y_line
# Out:
# array([210.80457868, 104.6239487 , 194.62467316, 142.03998022,
#        118.78136603, 114.73638965, 108.66892508, 151.14117707,
#        210.80457868, 189.56845268,  74.28662585, 169.34357078,
#        125.8600747 , 151.14117707, 128.89380698, 135.97251565,
#        192.60218497, 164.28735031, 143.05122431, 135.97251565,
#         99.56772822, 131.92753927, 149.11868888, 209.79333458,
#        186.5347204 , 141.02873612,  80.35409042, 208.78209049,
#        132.93878336, 147.09620069, 194.62467316,  91.47777546,
#        270.46798028, 105.63519279,  93.50026365, 123.83758651,
#        174.39979126, 163.27610621, 219.90577553, 166.3098385 ,
#        145.0737125 ,  89.45528727, 143.05122431, 130.91629517,
#        216.87204325, 119.79261012, 142.03998022,  84.3990668 ,
#        113.72514555, 166.3098385 , 146.0849566 , 168.33232669,
#        144.06246841, 137.99500384, 176.42227945, 106.64643689,
#        191.59094087,  93.50026365,  92.48901956, 128.89380698,
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=diabetes_X.reshape(442),y=diabetes_y.reshape(442),mode='markers',name='Dados Brutos'))
fig.add_trace(go.Scatter(x=diabetes_X.reshape(442),y=diabetes_y_line,name='Regressão Linear'))
fig.show()
# Out:
# <div>                            <div id="9c86b046-666e-47b1-9a0b-7a7e1813a2f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c86b046-666e-47b1-9a0b-7a7e1813a2f5")) {                    Plotly.newPlot(                        "9c86b046-666e-47b1-9a0b-7a7e1813a2f5",                        [{"mode":"markers","name":"Dados Brutos","type":"scatter","x":[0.0616962065186885,-0.0514740612388061,0.0444512133365941,-0.0115950145052127,-0.0363846922044735,-0.0406959404999971,-0.0471628129432825,-0.00189470584028465,0.0616962065186885,0.0390621529671896,-0.0838084234552331,0.0175059114895716,-0.0288400076873072,-0.00189470584028465,-0.0256065714656645,-0.0180618869484982,0.0422955891888323,0.0121168511201671,-0.0105172024313319,-0.0180618869484982,-0.0568631
# ...

# %%
diabetes_y_line = regr.predict(diabetes_X_train)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=diabetes_X_train.reshape(422),y=diabetes_y_train.reshape(422),mode='markers',name='Dados Brutos'))
fig.add_trace(go.Scatter(x=diabetes_X_train.reshape(422),y=diabetes_y_line,name='Regressão Linear'))
fig.show()
# Out:
# <div>                            <div id="59b9a22c-b1af-4948-839c-19c783b31a61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59b9a22c-b1af-4948-839c-19c783b31a61")) {                    Plotly.newPlot(                        "59b9a22c-b1af-4948-839c-19c783b31a61",                        [{"mode":"markers","name":"Dados Brutos","type":"scatter","x":[0.0616962065186885,-0.0514740612388061,0.0444512133365941,-0.0115950145052127,-0.0363846922044735,-0.0406959404999971,-0.0471628129432825,-0.00189470584028465,0.0616962065186885,0.0390621529671896,-0.0838084234552331,0.0175059114895716,-0.0288400076873072,-0.00189470584028465,-0.0256065714656645,-0.0180618869484982,0.0422955891888323,0.0121168511201671,-0.0105172024313319,-0.0180618869484982,-0.0568631
# ...

# %% [markdown]
# #  <a name="secao_1"> Questão 2 - Executar o exemplo de Ridge Regression </a>
# [Voltar ao índice](#indice)

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit([[0, 0], [0, 0], [1, 1]], [0, .1, 1])

print("Coeficiente Angular {}".format(reg.coef_))
print("Intercept {}".format(reg.intercept_))
# Out:
# Coeficiente Angular [0.34545455 0.34545455]
# Intercept 0.1363636363636364

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# X is the 10x10 Hilbert matrix
X = 1. / (np.arange(1, 11) + np.arange(0, 10)[:, np.newaxis])
y = np.ones(10)

# #############################################################################
# Compute paths

n_alphas = 200
alphas = np.logspace(-10, -2, n_alphas)

coefs = []
for a in alphas:
    ridge = linear_model.Ridge(alpha=a, fit_intercept=False)
    ridge.fit(X, y)
    coefs.append(ridge.coef_)

# #############################################################################
# Display results

ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
ridge_reg = linear_model.Ridge(alpha=.5)
ridge_reg.fit(diabetes_X_train, diabetes_y_train)

print("Coeficiente Angular {}".format(reg.coef_))
print("Intercept {}".format(reg.intercept_))
# Out:
# Coeficiente Angular [615.97080323]
# Intercept 153.0712635428958

# %%
diabetes_y_line1 = ridge_reg.predict(diabetes_X_train)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=diabetes_X_train.reshape(422),y=diabetes_y_train.reshape(422),mode='markers',name='Dados Brutos'))
fig.add_trace(go.Scatter(x=diabetes_X_test.reshape(20),y=diabetes_y_test.reshape(20),mode='markers',name='Dados Teste'))
fig.add_trace(go.Scatter(x=diabetes_X_train.reshape(422),y=diabetes_y_line,name='Regressão Linear'))
fig.add_trace(go.Scatter(x=diabetes_X_train.reshape(422),y=diabetes_y_line1,name='Ridge Regression'))
fig.show()
# Out:
# <div>                            <div id="0773e5ff-20c3-4bd0-8e33-43ad62d94765" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0773e5ff-20c3-4bd0-8e33-43ad62d94765")) {                    Plotly.newPlot(                        "0773e5ff-20c3-4bd0-8e33-43ad62d94765",                        [{"mode":"markers","name":"Dados Brutos","type":"scatter","x":[0.0616962065186885,-0.0514740612388061,0.0444512133365941,-0.0115950145052127,-0.0363846922044735,-0.0406959404999971,-0.0471628129432825,-0.00189470584028465,0.0616962065186885,0.0390621529671896,-0.0838084234552331,0.0175059114895716,-0.0288400076873072,-0.00189470584028465,-0.0256065714656645,-0.0180618869484982,0.0422955891888323,0.0121168511201671,-0.0105172024313319,-0.0180618869484982,-0.0568631
# ...

# %%
diabetes_y_pred_reg = ridge_reg.predict(diabetes_X_test)

# %%
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred_reg))
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred_reg))
# Out:
# Mean squared error: 3144.86
# Coefficient of determination: 0.35

# %% [markdown]
# #  <a name="conclusao"> Conclusão </a>
# [Voltar ao índice](#indice)

# %% [markdown]
# Escreva aqui suas conclusões...
